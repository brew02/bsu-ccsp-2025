# %%
from pathlib import Path 
from PIL import Image 
from IPython.display import display
from matplotlib import pyplot as plt
import numpy as np
import utils
from importlib import reload

reload(utils)
# Out:
# <module 'utils' from '/Users/devyn/REU/shared_git/bsu-ccsp-2025/grayscale_images/utils.py'>

# %% [markdown]
# # Gray Scale Image Visualization

# %% [markdown]
# **1) 00000b37a3**
#
# Sample 00000b37a3 was disassembled through Ghidra, and then edited by Code GBT's Gemini 2.5 Flash model to create an obfuscated version. I ran the obfuscated version through `convert_to_gray.py` and it did produce gray code. However, this script was intended to be run on binary code, not assembly code, so I am not positive the conversion was correct. Below is shown the original grayscale image and the obfuscated grayscale image.

# %%
sample_name = "00000b37a3d68384e9ce2c8f969ba3d839514ec6d3b234ed2285dff2aee644bd.bin.gray.png"
# utils.get_image(sample_name)
# utils.display_image(sample_name) # This displays image in Jupyter Notebook

obf_sample_name = "obf_00000b37a3d68384e9ce2c8f969ba3d839514ec6d3b234ed2285dff2aee644bd.bin.s.bin.gray.png"
# utils.get_image(obf_sample_name)
# utils.display_image(obf_sample_name) # This displays image in Jupyter Notebook

utils.compare_images(sample_name, obf_sample_name)
utils.pixel_hist(sample_name)
utils.pixel_hist(obf_sample_name)
# utils.compare_pixel_hists(sample_name, obf_sample_name)

# %% [markdown]
# **2) 00000cae80bac**

# %%
sample_name = "00000cae80bac4c4591dd2f4451d0d1543ecd8d62eb8bcdc22a6bd45ba738d7d.bin.gray.png"
obf_sample_name = "obf_00000cae80bac4c4591dd2f4451d0d1543ecd8d62eb8bcdc22a6bd45ba738d7d.bin.s.bin.gray.png"

utils.compare_images(sample_name, obf_sample_name)
utils.pixel_hist(sample_name)
utils.pixel_hist(obf_sample_name)

# %% [markdown]
# **3) 000001a2ccaa**

# %%
sample_name = "00001a2ccaa3e5b7f2a59fe23e6258bf97ae6c2845ca38665590267e55ed4b8c.bin.gray.png"
obf_sample_name = "obf_00001a2ccaa3e5b7f2a59fe23e6258bf97ae6c2845ca38665590267e55ed4b8c.bin.s.bin.gray.png"

utils.compare_images(sample_name, obf_sample_name)
utils.pixel_hist(sample_name)
utils.pixel_hist(obf_sample_name)
