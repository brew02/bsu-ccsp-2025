# %%
import utils
from importlib import reload
import os
from pathlib import Path

reload(utils)
# Out:
# <module 'utils' from '/Users/devyn/REU/shared_git/bsu-ccsp-2025/grayscale_images/utils.py'>

# %% [markdown]
# # Gray Scale Image Visualization

# %%
cwd = Path(os.getcwd())
dir = cwd / "images"

# %%
original = "helloWorld.gray.png"
obfuscated = "obf_helloWorld.gray.png"

utils.compare_images(original, obfuscated)
# utils.compare_pixel_hists(original, obfuscated)

# %%
original = "three_sum.gray.png"
obfuscated = "obf_three_sum.gray.png"

utils.compare_images(original, obfuscated)
# utils.compare_pixel_hists(original, obfuscated)

# %%
original = Path("/Users/devyn/REU/shared_git/bsu-ccsp-2025/grayscale_images/ascii_gray/00000b37a3d68384e9ce2c8f969ba3d839514ec6d3b234ed2285dff2aee644bd_extracted.asm.png")
original1 = Path("/Users/devyn/REU/shared_git/bsu-ccsp-2025/grayscale_images/ascii_gray/00001a2ccaa3e5b7f2a59fe23e6258bf97ae6c2845ca38665590267e55ed4b8c_extracted.asm.png")

utils.ssim_comparison(original, original1)
mse = utils.mse_comp(original, original1)
print(f"MSE: {mse}.")
# Out:
# MSE: 2129.90234375.
